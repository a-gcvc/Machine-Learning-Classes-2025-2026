# %%
import pandas as pd

# %%
df1=pd.read_csv("1_airline_passenger_satisfaction.csv")

# %%
df1.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business            821.0
# 1   2  Female   35     Returning       Business  Business            821.0
# 2   3    Male   41     Returning       Business  Business            853.0
# 3   4    Male   50     Returning       Business  Business           1905.0
# 4   5  Female   49     Returning       Business  Business           3470.0
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0              2.0            5.0                                     3.0
# 1             26.0           39.0                                     2.0
# 2              0.0            0.0                                     4.0
# 3              0.0            0.0                                     2.0
# 4              0.0            1.0                                     3.0
#
# ...

# %%
df1.dtypes
# Out:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                           float64
# Departure Delay                           float64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience    float64
# Ease of Online Booking                    float64
# Check-in Service                          float64
# Online Boarding                           float64
# Gate Location                             float64
# On-board Service                          float64
# Seat Comfort                              float64
# Leg Room Service                          float64
# Cleanliness                               float64
# Food and Drink                            float64
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42448 entries, 0 to 42447
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   ID                                      42448 non-null  int64
#  1   Gender                                  42448 non-null  object
#  2   Age                                     42448 non-null  int64
#  3   Customer Type                           42447 non-null  object
#  4   Type of Travel                          42447 non-null  object
#  5   Class                                   42447 non-null  object
#  6   Flight Distance                         42447 non-null  float64
#  7   Departure Delay                         42447 non-null  float64
#  8   Arrival Delay                           42283 non-null  float64
#  9   Departure and Arrival Time Convenience  42447 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                 ID           Age  Flight Distance  Departure Delay  \
# count  42448.00000  42448.000000     42447.000000     42447.000000
# mean   21224.50000     38.873516      1049.194077        15.638726
# std    12253.82645     15.098538       995.438988        40.921227
# min        1.00000      2.000000        31.000000         0.000000
# 25%    10612.75000     27.000000       351.000000         0.000000
# 50%    21224.50000     39.000000       657.000000         0.000000
# 75%    31836.25000     50.000000      1290.000000        11.000000
# max    42448.00000     85.000000      4983.000000      1017.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count   42283.000000                            42447.000000
# mean       16.931485                                3.064669
# std        41.803139                                1.536957
# min         0.000000                                0.000000
# ...

# %%
df1["Gender"].value_counts()
# Out:
# Gender
# Female    63448
# Male      61552
# Name: count, dtype: int64

# %%
df1["Customer Type"].value_counts()
# Out:
# Customer Type
# Returning     102150
# First-time     22850
# Name: count, dtype: int64

# %%
df1["Type of Travel"].value_counts()
# Out:
# Type of Travel
# Business    86340
# Personal    38660
# Name: count, dtype: int64

# %%
df1["Class"].value_counts()
# Out:
# Class
# Business        59496
# Economy         56343
# Economy Plus     9161
# Name: count, dtype: int64

# %%
df1["Satisfaction"].value_counts()
# Out:
# Satisfaction
# Neutral or Dissatisfied    70752
# Satisfied                  54248
# Name: count, dtype: int64

# %%
df1["Gender"].value_counts(normalize=True) * 100
# Out:
# Gender
# Female    50.7584
# Male      49.2416
# Name: proportion, dtype: float64

# %%
df1["Customer Type"].value_counts(normalize=True) * 100
# Out:
# Customer Type
# Returning     81.72
# First-time    18.28
# Name: proportion, dtype: float64

# %%
df1["Type of Travel"].value_counts(normalize=True) * 100
# Out:
# Type of Travel
# Business    69.072
# Personal    30.928
# Name: proportion, dtype: float64

# %%
df1["Class"].value_counts(normalize=True) * 100
# Out:
# Class
# Business        47.5968
# Economy         45.0744
# Economy Plus     7.3288
# Name: proportion, dtype: float64

# %%
df1["Satisfaction"].value_counts(normalize=True) * 100
# Out:
# Satisfaction
# Neutral or Dissatisfied    56.6016
# Satisfied                  43.3984
# Name: proportion, dtype: float64

# %%
# aritmetička sredina
mean = df1["Age"].mean()

# medijan
median = df1["Age"].median()

# moda
mode = df1["Age"].mode()

# minimum
min_val = df1["Age"].min()

# maksimum
max_val = df1["Age"].max()

print(mean, median, mode, min_val, max_val)
# Out:
# 39.420872 40.0 0    39
# Name: Age, dtype: int64 7 85

# %%
# aritmetička sredina
mean = df1["Flight Distance"].mean()

# medijan
median = df1["Flight Distance"].median()

# moda
mode = df1["Flight Distance"].mode()

# minimum
min_val = df1["Flight Distance"].min()

# maksimum
max_val = df1["Flight Distance"].max()

print(mean, median, mode, min_val, max_val)
# Out:
# 1180.574136 834.0 0    337
# Name: Flight Distance, dtype: int64 31 4983

# %%
# aritmetička sredina
mean = df1["Departure Delay"].mean()

# medijan
median = df1["Departure Delay"].median()

# moda
mode = df1["Departure Delay"].mode()

# minimum
min_val = df1["Departure Delay"].min()

# maksimum
max_val = df1["Departure Delay"].max()

print(mean, median, mode, min_val, max_val)
# Out:
# 14.93268 0.0 0    0
# Name: Departure Delay, dtype: int64 0 1592

# %%
# aritmetička sredina
mean = df1["Arrival Delay"].mean()

# medijan
median = df1["Arrival Delay"].median()

# moda
mode = df1["Arrival Delay"].mode()

# minimum
min_val = df1["Arrival Delay"].min()

# maksimum
max_val = df1["Arrival Delay"].max()

print(mean, median, mode, min_val, max_val)
# Out:
# 15.289173834895365 0.0 0    0.0
# Name: Arrival Delay, dtype: float64 0.0 1584.0

# %%
df1["Departure and Arrival Time Convenience"].value_counts()
# Out:
# Departure and Arrival Time Convenience
# 4    30679
# 5    27036
# 3    21534
# 2    20668
# 1    18662
# 0     6421
# Name: count, dtype: int64

# %%
df1["Departure and Arrival Time Convenience"].mean()
# Out:
# np.float64(3.059968)

# %%
bez_nula = df1["Departure and Arrival Time Convenience"][df1["Departure and Arrival Time Convenience"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 3.23

# %%
df1["Ease of Online Booking"].value_counts()
# Out:
# Ease of Online Booking
# 3    29197
# 2    28930
# 4    23510
# 1    21055
# 5    16789
# 0     5519
# Name: count, dtype: int64

# %%
df1["Ease of Online Booking"].mean()
# Out:
# np.float64(2.755928)

# %%
bez_nula = df1["Ease of Online Booking"][df1["Ease of Online Booking"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 2.88

# %%
df1["Check-in Service"].value_counts()
# Out:
# Check-in Service
# 4    34883
# 3    34038
# 5    24895
# 2    15607
# 1    15576
# 0        1
# Name: count, dtype: int64

# %%
df1["Check-in Service"].mean()
# Out:
# np.float64(3.303288)

# %%
bez_nula = df1["Check-in Service"][df1["Check-in Service"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 3.30

# %%
df1["Online Boarding"].value_counts()
# Out:
# Online Boarding
# 4    37041
# 3    26085
# 5    24944
# 2    21145
# 1    12787
# 0     2998
# Name: count, dtype: int64

# %%
df1["Online Boarding"].mean()
# Out:
# np.float64(3.249728)

# %%
bez_nula = df1["Online Boarding"][df1["Online Boarding"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 3.33

# %%
df1["Gate Location"].value_counts()
# Out:
# Gate Location
# 3    34409
# 4    29276
# 2    23371
# 1    21164
# 5    16779
# 0        1
# Name: count, dtype: int64

# %%
df1["Gate Location"].mean()
# Out:
# np.float64(2.977056)

# %%
bez_nula = df1["Gate Location"][df1["Gate Location"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 2.98

# %%
df1["On-board Service"].mean()
# Out:
# np.float64(3.2780172921525668)

# %%
bez_nula = df1["On-board Service"][df1["On-board Service"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 3.28

# %%
df1["On-board Service"].value_counts()
# Out:
# On-board Service
# 4.0    11833
# 3.0     9135
# 5.0     9071
# 2.0     6644
# 1.0     5762
# 0.0        2
# Name: count, dtype: int64

# %%
df1["Seat Comfort"].mean()
# Out:
# np.float64(3.3480575776851134)

# %%
bez_nula = df1["Seat Comfort"][df1["Seat Comfort"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 3.35

# %%
df1["Seat Comfort"].value_counts()
# Out:
# Seat Comfort
# 4.0    12276
# 5.0     9924
# 3.0     8304
# 2.0     6537
# 1.0     5405
# 0.0        1
# Name: count, dtype: int64

# %%
df1["Leg Room Service"].mean()
# Out:
# np.float64(3.265295545032629)

# %%
bez_nula = df1["Leg Room Service"][df1["Leg Room Service"] != 0]

mean_bez_nula = bez_nula.mean()
print(f"Aritmetička sredina bez nula: {mean_bez_nula:.2f}")
# Out:
# Aritmetička sredina bez nula: 3.28

# %%
df1["Seat Comfort"].value_counts()
# Out:
# Seat Comfort
# 4.0    12276
# 5.0     9924
# 3.0     8304
# 2.0     6537
# 1.0     5405
# 0.0        1
# Name: count, dtype: int64

# %%
kolone = ["Cleanliness", "Food and Drink", "In-flight Service",
          "In-flight Wifi Service", "In-flight Entertainment", "Baggage Handling"]

# Aritmetička sredina uključujući sve vrednosti
mean_all = df1[kolone].mean()
print("Srednja vrednost svih ocena:\n", mean_all)

# Aritmetička sredina bez nula
mean_bez_nula = df1[kolone].replace(0, pd.NA).mean()
print("\nSrednja vrednost bez nula:\n", mean_bez_nula)
# Out:
# Srednja vrednost svih ocena:
#  Cleanliness                3.240158
# Food and Drink             3.205645
# In-flight Service          3.507763
# In-flight Wifi Service     2.769407
# In-flight Entertainment    3.351167
# Baggage Handling           3.511862
# dtype: float64
#
# Srednja vrednost bez nula:
#  Cleanliness                3.240616
# Food and Drink             3.209349
# In-flight Service          3.507928
# In-flight Wifi Service     2.865818
# In-flight Entertainment     3.35172
# Baggage Handling           3.511862
# dtype: object
